# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
train_processed = np.load('../data/Processed/data_train_FGS.npy')

# %%
train_processed.shape
# Out:
# (6, 187, 32, 32)

# %%
plt.plot(train_processed[1].sum(axis=(1, 2)))
